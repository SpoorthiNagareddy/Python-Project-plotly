# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import warnings
import plotly.graph_objects as go
from scipy.interpolate import griddata

# %%
warnings.simplefilter("ignore")
df_coffee = pd.read_excel('/content/coffee chain data (1).xlsx', engine='openpyxl')

# %%
df_coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248 entries, 0 to 4247
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Area Code       4248 non-null   int64
#  1   Date            4248 non-null   datetime64[ns]
#  2   Market Size     4248 non-null   object
#  3   Market          4248 non-null   object
#  4   Product Line    4248 non-null   object
#  5   Product Type    4248 non-null   object
#  6   Product         4248 non-null   object
#  7   State           4248 non-null   object
#  8   Type            4248 non-null   object
#  9   Budget COGS     4248 non-null   int64
#  10  Budget Margin   4248 non-null   int64
#  11  Budget Profit   4248 non-null   int64
#  12  Budget Sales    4248 non-null   int64
#  13  COGS            4248 non-null   int64
#  14  Inventory       4248 non-null   int64
#  15  Margin          4248 non-null   int64
#  16  Marketing       4248 non-null   int64
#  17  Profit          4248 non-null   int64
#  18  Sales           4248 non-null   int64
#  19  Total Expenses  4248 non-null   int64
# dtypes: datetime64[ns](1), int64(12), object(7)
# memory usage: 663.9+ KB

# %%
df_coffee['Date'] = pd.to_datetime(df_coffee['Date'])

sales_trend = df_coffee.groupby(['Date', 'Product Type'])['Sales'].sum().reset_index()

fig = px.line(sales_trend, x='Date', y='Sales', color='Product Type',
              title='Sales Trend Over Time by Product Type',
              labels={'Date': 'Date', 'Sales': 'Total Sales', 'Product Type': 'Product Type'},
              markers=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8b8afb78-73b6-46a6-8bac-4b7b1dd91214" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b8afb78-73b6-46a6-8bac-4b7b1dd91214")) {                    Plotly.newPlot(                        "8b8afb78-73b6-46a6-8bac-4b7b1dd91214",                        [{"hovertemplate":"Product Type=Coffee\u003cbr\u003eDate=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coffee","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Coffee","orientation":"v","showlegend":true,"x":["2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00"],"xaxis":"x","y":[8314,8327,8407,8685,8945,9557,9913,9787,8844,8363,8220,8772,9305,8872,8958,9257,8865,9470,9821,9702,9426,8909,8759,9350],"yaxis":"y","type":"scatter"},{"hovertemplate":"Product Type=Espresso\u003cbr\u003eDate=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Espresso","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Espresso","orientation":"v","showlegend":true,"x":["2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00"],"xaxis":"x","y":[8716,8960,8951,8969,9071,9361,9463,9538,8941,9192,8942,8982,9753,9545,9536,9559,8991,9276,9377,9448,9528,9790,9530,9577],"yaxis":"y","type":"scatter"},{"hovertemplate":"Product Type=Herbal Tea\u003cbr\u003eDate=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Herbal Tea","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Herbal Tea","orientation":"v","showlegend":true,"x":["2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00"],"xaxis":"x","y":[7874,8046,8077,8367,8517,8852,9318,9163,8169,8276,8157,8589,8814,8574,8606,8918,8440,8771,9232,9083,8708,8816,8691,9156],"yaxis":"y","type":"scatter"},{"hovertemplate":"Product Type=Tea\u003cbr\u003eDate=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tea","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Tea","orientation":"v","showlegend":true,"x":["2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2 ...

# %%
fig = px.box(df_coffee, x='Market Size', y='Sales',
              title='Sales Distribution by Market Size',
              labels={'Market Size': 'Market Size', 'Sales': 'Sales'},
              color='Market Size')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="98b49ca8-453d-4f40-bb9d-7ac213bc485d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
171,178,190,206,153,184,169,173,178,163,189,170,94,137,125,44,50,69,64,39,52,35,90,70,54,842,117,87,275,213,218,267,210,678,108,104,119,136,146,84,93,114,127,137,125,137,126,85,89,93,107,150,745,165,882,759,759,842,68,72,55,77,52,52,50,67,60,68,52,68,61,47,119,88,109,117,133,137,168,127,85,118,103,125,107,125,128,239,160,213,250,211,169,142,190,664,665,171,130,130,116,116,121,123,148,138,159,167,159,140,155,135,131,142,133,113,127,109,121,111,134,160,122,122,109,109,114,139,115,160,139,160,169,141,156,136,132,133,125,119,106,102,114,99,120,83,134,117,143,129,123,100,78,126,118,154,86,115,121,153,130,114,134,84,94,92,111,106,133,165,179,168,101,98,112,114,85,128,107,119,149,125,121,155,160,273,225,232,309,310,119,527,133,123,128,121,148,196,132,160,189,118,151,160,145,97,109,167,99,167,107,141,171,112,147,127,201,174,206,139,145,153,139,124,177,111,142,113,160,98,169,132,169,142,173,113,148,178,119,167,163,189,193,130,165,130,522,554,190,188,202,496,567,512,178,209,156,230,211,193,107,112,107,160,109,160,169,645,208,245,134,212,139,129,201,223,149,231,195,188,180,180,553,576,494,559,452,135,236,205,70,98,84,104,107,185,155,55,57,60,71,75,106,79,80, ...

# %%
state_abbreviations = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO',
    'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
    'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA',
    'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
    'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD',
    'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

df_coffee['State_Abbr'] = df_coffee['State'].map(state_abbreviations)

sales_by_state = df_coffee.groupby('State_Abbr')['Sales'].sum().reset_index()

fig6 = px.choropleth(sales_by_state,
                     locations='State_Abbr',
                     locationmode='USA-states',
                     color='Sales',
                     scope='usa',
                     title='Total Sales by State',
                     labels={'Sales': 'Total Sales'})

fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="256028c2-ea8f-48db-8787-50f776473233" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("256028c2-ea8f-48db-8787-50f776473233")) {                    Plotly.newPlot(                        "256028c2-ea8f-48db-8787-50f776473233",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State_Abbr=%{location}\u003cbr\u003eTotal Sales=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["CA","CO","CT","FL","IA","IL","LA","MA","MO","NH","NM","NV","NY","OH","OK","OR","TX","UT","WA","WI"],"name":"","z":[96892,48179,25429,37443,54750,69883,23161,29965,24647,14887,15892,60159,70852,34517,27463,40899,37410,35384,38930,33069],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scatterg ...

# %%
fig = px.sunburst(df_coffee,
                  path=['State', 'Market Size', 'Product Line'],
                  values='Sales',
                  title="Sunburst Chart: Sales Breakdown by State, Market Size, and Product Line",
                  color='Sales',
                  color_continuous_scale='RdBu'
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="23a48016-c2a6-4bc9-b7b6-1c2a77fc3f6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23a48016-c2a6-4bc9-b7b6-1c2a77fc3f6b")) {                    Plotly.newPlot(                        "23a48016-c2a6-4bc9-b7b6-1c2a77fc3f6b",                        [{"branchvalues":"total","customdata":[[550.096123531705],[226.446973903387],[242.89498659870821],[494.79860753542727],[433.79872819311385],[673.2415083393763],[205.36423670226486],[342.296443686438],[218.86357805779824],[55.044537007369435],[132.5353575184017],[144.1434117555711],
show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="964f8a86-2aba-40a1-b7f7-81fe68cdf8b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("964f8a86-2aba-40a1-b7f7-81fe68cdf8b4")) {                    Plotly.newPlot(                        "964f8a86-2aba-40a1-b7f7-81fe68cdf8b4",                        [{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaretto","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Amaretto","offsetgroup":"Amaretto","orientation":"v","showlegend":true,"textposition":"auto","x":["Amaretto"],"xaxis":"x","y":[1082],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Caffe Latte","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Caffe Latte","offsetgroup":"Caffe Latte","orientation":"v","showlegend":true,"textposition":"auto","x":["Caffe Latte"],"xaxis":"x","y":[1478],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Caffe Mocha","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Caffe Mocha","offsetgroup":"Caffe Mocha","orientation":"v","showlegend":true,"textposition":"auto","x":["Caffe Mocha"],"xaxis":"x","y":[3220],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chamomile","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chamomile","offsetgroup":"Chamomile","orientation":"v","showlegend":true,"textposition":"auto","x":["Chamomile"],"xaxis":"x","y":[2960],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colombian","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Colombian","offsetgroup":"Colombian","orientation":"v","showlegend":true,"textposition":"auto","x":["Colombian"],"xaxis":"x","y":[4860],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Darjeeling","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Darjeeling","offsetgroup":"Darjeeling","orientation":"v","showlegend":true,"textposition":"auto","x":["Darjeeling"],"xaxis":"x","y":[2839],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decaf Espresso","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Decaf Espresso","offsetgroup":"Decaf Espresso","orientation":"v","showlegend":true,"textposition":"auto","x":["Decaf Espresso"],"xaxis":"x","y":[3122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decaf Irish Cream","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Decaf Irish Cream","offsetgroup":"Decaf Irish Cream","orientation":"v","showlegend":true,"textposition":"auto","x":["Decaf Irish Cream"],"xaxis":"x","y":[2372],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product=%{x}\u003cbr\u003eanimation_frame=2012-01\u003cbr\u003eSales=%{y}\u003cextra\u ...

# %%
df_coffee['Date'] = pd.to_datetime(df_coffee['Date'])
sales_coffee = df_coffee.groupby('Product')['Sales'].sum().reset_index()
fig_polar = px.bar_polar(sales_coffee, r='Sales', theta='Product', color='Product',
                         title='Sales Contribution by Coffee Type (Polar Chart)',
                         template='plotly_dark')
fig_polar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6829193a-1298-4e6c-9c7b-304907f84998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6829193a-1298-4e6c-9c7b-304907f84998")) {                    Plotly.newPlot(                        "6829193a-1298-4e6c-9c7b-304907f84998",                        [{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaretto","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Amaretto","r":[26269],"showlegend":true,"subplot":"polar","theta":["Amaretto"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Caffe Latte","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Caffe Latte","r":[35899],"showlegend":true,"subplot":"polar","theta":["Caffe Latte"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Caffe Mocha","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Caffe Mocha","r":[84904],"showlegend":true,"subplot":"polar","theta":["Caffe Mocha"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chamomile","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chamomile","r":[75578],"showlegend":true,"subplot":"polar","theta":["Chamomile"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colombian","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Colombian","r":[128311],"showlegend":true,"subplot":"polar","theta":["Colombian"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Darjeeling","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Darjeeling","r":[73151],"showlegend":true,"subplot":"polar","theta":["Darjeeling"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decaf Espresso","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Decaf Espresso","r":[78162],"showlegend":true,"subplot":"polar","theta":["Decaf Espresso"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decaf Irish Cream","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Decaf Irish Cream","r":[62248],"showlegend":true,"subplot":"polar","theta":["Decaf Irish Cream"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Earl Grey","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Earl Grey","r":[66772],"showlegend":true,"subplot":"polar","theta":["Earl Grey"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Green Tea","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Green Tea","r":[32850],"showlegend":true,"subplot":"polar","theta":["Green Tea"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lemon","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Lemon","r":[95926],"showlegend":true,"subplot":"polar","theta":["Lemon"],"type":"barpolar"},{"hovertemplate":"Product=%{theta}\u003cbr\u003eSales=%{r}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mint","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Mint","r":[35710],"showlegend":true,"subplot":"polar","theta":["Mint" ...

# %%
fig = px.scatter_3d(df, x="Sales", y="Profit", z="Margin",
                     color="Product Type", hover_data=["Product", "Market"],
                     title="3D Scatter Plot of Sales, Profit, and Margin")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="813daa12-d0b7-4946-9427-fd9ca2acc203" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("813daa12-d0b7-4946-9427-fd9ca2acc203")) {                    Plotly.newPlot(                        "813daa12-d0b7-4946-9427-fd9ca2acc203",                        [{"customdata":[["Colombian","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Colombian","South"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Colombian","South"],["Colombian","South"],["Colombian","South"],["Amaretto","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Colombian","West"],["Amaretto","West"],["Colombian","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Amaretto","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Colombian","Central"],["Amaretto","Central"],["Colombian","Central"],["Colombian","Central"],["Colombian","Central"],["Amaretto","Central"],["Colombian","Central"],["Colombian","Central"],["Colombian","Central"],["Amaretto","Central"],["Decaf Irish Cream","Central"],["Amaretto","Central"],["Decaf Irish Cream","Central"],["Colombian","Central"],["Amaretto","Central"],["Colombian","Central"],["Decaf Irish Cream","Central"],["Colombian","Central"],["Colombian","Central"],["Colombian","Central"],["Decaf Irish Cream","Central"],["Colombian","Central"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Decaf Irish Cream","South"],["Colombian","South"],["Decaf Irish Cream","South"],["Colombian","East"],["Colombian","East"],["Decaf Irish Cream","East"],["Decaf Irish Cream","East"],["Colombian","East"],["Decaf Irish Cream","West"],["Amaretto","West"],["Colombian","West"],["Decaf Irish Cream","West"],["Colombian","West"],["Colombian","East"],["Colombian","South"],["Decaf Irish Cream","South"],["Colombian","South"],["Colombian","Central"],["Colombian","Central"],["Decaf Irish Cream","Central"],["Amaretto","Central"],["Amaretto","Central"],["Decaf Irish Cream","South"],["Colombian","South"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Amaretto","West"],["Amaretto","Central"],["Decaf Irish Cream","Central"],["Decaf Irish Cream","Central"],["Colombian","Central"],["Decaf Irish Cream","Central"],["Amaretto","Central"],["Decaf Irish Cream","Central"],["Amaretto","Central"],["Colombian","Central"],["Decaf Irish Cream","South"],["Colombian","South"],["Colombian","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Colombian","South"],["Colombian","South"],["Decaf Irish Cream","South"],["Colombian","South"],["Decaf Irish Cream","South"],["Colombian","South"],["Colombian","South"],["Colombian","South"],["Colombian","South"],["Colombian","East"],["Colombian","East"],["Colombian","East"],["Amaretto","West"],["Amaretto","West"],["Decaf Irish Cream","West"],["Amaretto","West"],["Decaf Irish Cream","South"],["Decaf Irish Cream","South"],["Colombian","East"],["Amaretto","West"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Decaf Irish Cream","West"],["Amaretto","West"],["Decaf Irish Cream","East"],["Colombian","East"],["Colombian","East"], ...

# %%
df_coffee = df_coffee.dropna(subset=["Sales", "Profit", "Inventory"])

# Extract necessary columns
x = df_coffee["Sales"].values   # X-axis: Product Sales
y = df_coffee["Profit"].values  # Y-axis: Profit
z = df_coffee["Inventory"].values  # Z-axis: Inventory (or use 'Revenue' if available)

# Define grid size
grid_x, grid_y = np.mgrid[x.min():x.max():30j, y.min():y.max():30j]

# Interpolate inventory values using griddata
grid_z = griddata((x, y), z, (grid_x, grid_y), method='cubic')

# Create a 3D surface plot
fig_surface = go.Figure(data=[go.Surface(z=grid_z, x=grid_x, y=grid_y)])

fig_surface.update_layout(
    title="3D Surface Plot of Product Sales, Profit, and Inventory",
    scene=dict(
        xaxis_title="Product Sales",
        yaxis_title="Profit",
        zaxis_title="Inventory"
    )
)

# Show the plot
fig_surface.show()

# Save the plot as an interactive HTML file
fig_surface.write_html("3d_surface_product_sales_profit.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec7c71b4-f021-427c-bfc0-c2074b943349" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec7c71b4-f021-427c-bfc0-c2074b943349")) {                    Plotly.newPlot(                        "ec7c71b4-f021-427c-bfc0-c2074b943349",                        [{"x":[[17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0],[47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724,47.86206896551724],[78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448,78.72413793103448],[109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173,109.58620689655173],[140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895,140.44827586206895],[171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622,171.31034482758622],[202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,202.17241379310346,20 ...
